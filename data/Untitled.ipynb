# %%
import pandas as pd

# %%
read_file = '/work/frink/ramprasad.sa/uncertainty_hallucination/datasets/Annotations/first_batch_final4_annotator_dump_oct_28.csv'

# %%
df = pd.read_csv(read_file)
df
# Out:
#      Unnamed: 0                                  uuid user_id  \
# 0            16  269fd2e3-77fe-4e4e-975b-d9d757ceacec  YtYC5w
# 1            17  1ba057f2-2533-43b5-996d-a5a9e6295cdf  YtYC5w
# 2            18  843c9c05-b43a-4c07-84d1-799fff379221  YtYC5w
# 3            19  0ecee683-10c8-4229-befb-51d7da379229  YtYC5w
# 4            36  66a09755-6b0f-44ae-b77d-eb008e67c3fb  YtYC5w
# ..          ...                                   ...     ...
# 321         454  f5841676-7b9c-4cb9-a556-89b9f61e3f94  4vQZBQ
# 322         455  feaefc3b-41f5-4fbb-9ba8-49bdaf03a27b  4vQZBQ
# 323         456  8fef3ffe-0a04-4710-814b-c042f7a6e450  4vQZBQ
# 324         457  394beeb3-36e2-4219-8ab2-666172f01944  4vQZBQ
# 325         458  c510e4a6-e001-45eb-9360-e22ed1b753af  4vQZBQ
#
#                             docid  \
# 0      XSUM-29928061:llama70b-ul2
# 1    ACIBENCH-D2N124:falcon7b-ul2
# 2    ACIBENCH-D2N124:falcon7b-ul2
# 3    ACIBENCH-D2N124:falcon7b-ul2
# 4          XSUM-29928061:gpt4-ul2
# ...

# %%
df = df[df['origin'] == 'REDDIT']
df
# Out:
#      Unnamed: 0                                  uuid user_id  \
# 20           60  3578a38d-d4e8-4820-927f-6cb9e2957ccc  4vQZBQ
# 21           65  991a9146-c1be-43d5-a9cd-01df49336420  4vQZBQ
# 22           66  a78c939d-5d40-45c1-b059-7d30f6cca547  4vQZBQ
# 23           78  7352897c-e7c8-4653-bf91-f32d4a8b8199  4vQZBQ
# 26           83  41979b4d-12a8-4b8c-84c4-678cd5645e16  4vQZBQ
# ..          ...                                   ...     ...
# 318         451  b0749a91-c92b-4880-bec2-e4f5ac15d276  4vQZBQ
# 319         452  8770399c-ce7f-4940-afff-b0b33b34fb27  4vQZBQ
# 320         453  390369d6-b38e-4c4f-82f8-2cdfe8c437ae  4vQZBQ
# 321         454  f5841676-7b9c-4cb9-a556-89b9f61e3f94  4vQZBQ
# 322         455  feaefc3b-41f5-4fbb-9ba8-49bdaf03a27b  4vQZBQ
#
#                       docid  \
# 20       REDDIT-83:gpt4-ul2
# 21       REDDIT-83:gpt4-ul2
# 22       REDDIT-83:gpt4-ul2
# 23       REDDIT-54:gpt4-ul2
# 26   REDDIT-54:llama70b-ul2
# ..                      ...
# ...

# %%
df = df[df['model'] == 'gpt4']
set(df['docid'])
# Out:
# {'REDDIT-18:gpt4-ul2',
#  'REDDIT-19:gpt4-ul2',
#  'REDDIT-54:gpt4-ul2',
#  'REDDIT-73:gpt4-ul2',
#  'REDDIT-83:gpt4-ul2'}

# %%
[{"id": "test_127", "origin": "DialogSum", "context": "#Person1#: Could you tell me what university you went to, Mr. Smith?\n#Person2#: I went to Yale University.\n#Person1#: Did you? And what did you study?\n#Person2#: I have a B. A. in Economics.\n#Person1#: Would you mind telling me how old you are?\n#Person2#: I&#39;m twenty-seven.\n#Person1#: And could you tell me what other jobs you have had?\n#Person2#: Yes, I have worked in a bank for the last five years.\n#Person1#: And what was your salary at the bank?\n#Person2#: I got $ 500 a week.", "source": "MrMr. Smith tells #Person1# he went to Yale University and worked in a bank."}]



for docid in set(df['docid']):
    df_doc = df[df['docid'] == docid]
    ann_data = {
        "id": docid,
        "origin": "REDDIT",
        "context": df_doc['source'].values[0]
        "
    }

# %%
df_doc
# Out:
#      Unnamed: 0                                  uuid user_id  \
# 20           60  3578a38d-d4e8-4820-927f-6cb9e2957ccc  4vQZBQ
# 21           65  991a9146-c1be-43d5-a9cd-01df49336420  4vQZBQ
# 22           66  a78c939d-5d40-45c1-b059-7d30f6cca547  4vQZBQ
# 43          110  87f019ad-1966-409b-9309-b835d912a194  g7wLBw
# 127         260  11c0d14e-7660-45ae-8f06-f016960ab56b  YtYC5w
# 128         261  22031144-0597-4807-ac38-2124a0274836  YtYC5w
# 129         262  a68fee6a-7b1e-4a1e-accb-a49078aa4cc9  YtYC5w
# 130         263  0f5a3d14-5332-494b-9303-b886054bd5f7  YtYC5w
# 131         264  902b5419-6e51-445b-a89b-1498cf4e8dc4  YtYC5w
# 132         265  644f576c-63ef-4e4e-a3c0-7d79e5c9b49d  YtYC5w
# 133         266  ee8e6fe1-40e8-4d34-b127-267a8bc54b0e  YtYC5w
# 176         309  85574c96-948f-415a-8f23-dd5f66a779b1  USzArg
# 177         310  8b045c29-42f7-4cc9-8e88-a5df72816940  USzArg
# 178         311  d1f53f3c-ba43-46fb-8ee4-5d132a4f8858  USzArg
# ...
